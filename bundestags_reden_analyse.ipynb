# %% [markdown]
# <a href="https://colab.research.google.com/github/Roby290597/nlp_exercise/blob/main/bundestags_reden_analyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os 
import matplotlib.pyplot as plt

import xml.etree.ElementTree as ET
import requests
import sys 
sys.path.append("extr")
from redner_extraction import extract_all_speakers, extract_speaker_party
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 8
#       6 import sys
#       7 sys.path.append("extr")
# ----> 8 from redner_extraction import extract_all_speakers, extract_speaker_party
#
# ImportError: cannot import name 'extract_speaker_party' from 'redner_extraction' (c:\Users\brand\OneDrive\Desktop\AI_Selbststudium\ML_little\bundestag_reden\extr\redner_extraction.py)

# %%
url = "https://www.bundestag.de/resource/blob/1115000/21032.xml"
response = requests.get(url)

# XML in einen Tree parsen
tree = ET.ElementTree(ET.fromstring(response.content))

# Wurzel-Element abrufen
root = tree.getroot()

print(root.keys())
# Out:
# ['vertrieb', 'herstellung', 'sitzung-ort', 'herausgeber', 'issn', 'wahlperiode', 'sitzung-nr', 'sitzung-datum', 'sitzung-start-uhrzeit', 'sitzung-ende-uhrzeit', 'sitzung-naechste-datum', 'start-seitennr']

# %% [markdown]
# ### Extraktion der Reden mitsamt Redner

# %%
reden = {}
redner = []
# Beispiel-Ausgabe
for speech in extract_speeches(root):
    #print(f"Redner: {speech['name']}\nRede: {speech['text'][:200]}...\n")
    if speech['name'] not in redner:
        redner.append(speech['name'])
        reden[speech['name']] = speech['text']
    else:
        print("DOPPELT:", speech['name'])
        reden[speech['name']] += "\n Nächste Rede:" + speech['text']
# Out:
# DOPPELT: Mandy Eißing
# DOPPELT: Peter Bohnhof
# DOPPELT: Mahmut Özdemir
# DOPPELT: Klaus Wiener
# DOPPELT: Mirze Edis

# %%
redner_party = []
all_speakers = extract_all_speakers(root)
for speaker in all_speakers:
    print(speaker)
    redner_party.append((speaker['vorname'] + " " + speaker['nachname'], speaker['fraktion']))
# Out:
# {'vorname': 'Bärbel', 'nachname': 'Bas', 'fraktion': ''}
# {'vorname': 'Hans-Jürgen', 'nachname': 'Goßner', 'fraktion': 'AfD'}
# {'vorname': 'Wilfried', 'nachname': 'Oellers', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Ricarda', 'nachname': 'Lang', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Pascal', 'nachname': 'Meiser', 'fraktion': 'Die Linke'}
# {'vorname': 'Dagmar', 'nachname': 'Schmidt', 'fraktion': 'SPD'}
# {'vorname': 'Peter', 'nachname': 'Bohnhof', 'fraktion': 'AfD'}
# {'vorname': 'Sandra', 'nachname': 'Carstensen', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Armin', 'nachname': 'Grau', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Nora', 'nachname': 'Seitz', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Leif-Erik', 'nachname': 'Holm', 'fraktion': 'AfD'}
# {'vorname': 'Peter', 'nachname': 'Aumer', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Jan', 'nachname': 'Dieren', 'fraktion': 'SPD'}
# {'vorname': 'Elisabeth', 'nachname': 'Winkelmeier-Becker', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Tobias Matthias', 'nachname': 'Peterka', 'fraktion': 'AfD'}
# {'vorname': 'Axel', 'nachname': 'Müller', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Lena', 'nachname': 'Gumnior', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Mahmut', 'nachname': 'Özdemir', 'fraktion': 'SPD'}
# {'vorname': 'Luke', 'nachname': 'Hoß', 'fraktion': 'Die Linke'}
# {'vorname': 'Christian', 'nachname': 'Moser', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Rainer', 'nachname': 'Galla', 'fraktion': 'AfD'}
# {'vorname': 'Maja', 'nachname': 'Wallstein', 'fraktion': 'SPD'}
# {'vorname': 'Helge', 'nachname': 'Limburg', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Johannes', 'nachname': 'Wiegelmann', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Knuth', 'nachname': 'Meyer-Soltau', 'fraktion': 'AfD'}
# {'vorname': 'David', 'nachname': 'Preisendanz', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Wolfram', 'nachname': 'Weimer', 'fraktion': ''}
# {'vorname': 'Götz', 'nachname': 'Frömming', 'fraktion': 'AfD'}
# {'vorname': 'Elisabeth', 'nachname': 'Kaiser', 'fraktion': ''}
# {'vorname': 'Katrin', 'nachname': 'Göring-Eckardt', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Mandy', 'nachname': 'Eißing', 'fraktion': 'Die Linke'}
# {'vorname': 'Ottilie', 'nachname': 'Klein', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Sven', 'nachname': 'Wendorf', 'fraktion': 'AfD'}
# {'vorname': 'Franziska', 'nachname': 'Kersten', 'fraktion': 'SPD'}
# {'vorname': 'Sepp', 'nachname': 'Müller', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Wolfgang', 'nachname': 'Dahler', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Birgit', 'nachname': 'Bessin', 'fraktion': 'AfD'}
# {'vorname': 'Felix', 'nachname': 'Döring', 'fraktion': 'SPD'}
# {'vorname': 'Misbah', 'nachname': 'Khan', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Konrad', 'nachname': 'Körner', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Anna', 'nachname': 'Rathert', 'fraktion': 'AfD'}
# {'vorname': 'Reem', 'nachname': 'Alabali Radovan', 'fraktion': ''}
# {'vorname': 'Rocco', 'nachname': 'Kever', 'fraktion': 'AfD'}
# {'vorname': 'Nicolas', 'nachname': 'Zippelius', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Claudia', 'nachname': 'Roth', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Mirze', 'nachname': 'Edis', 'fraktion': 'Die Linke'}
# {'vorname': 'Klaus', 'nachname': 'Wiener', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Johann', 'nachname': 'Martel', 'fraktion': 'AfD'}
# {'vorname': 'Thomas', 'nachname': 'Bareiß', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Matthias', 'nachname': 'Gastel', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Michael', 'nachname': 'Donth', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Ulrich', 'nachname': 'von Zons', 'fraktion': 'AfD'}
# {'vorname': 'Anja', 'nachname': 'Troff-Schaffarzyk', 'fraktion': 'SPD'}
# {'vorname': 'Luigi', 'nachname': 'Pantisano', 'fraktion': 'Die Linke'}
# {'vorname': 'Henning', 'nachname': 'Rehbaum', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Maximilian', 'nachname': 'Kneller', 'fraktion': 'AfD'}
# {'vorname': 'Jakob', 'nachname': 'Blankenburg', 'fraktion': 'SPD'}
# {'vorname': 'Günter', 'nachname': 'Baumgartner', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Katherina', 'nachname': 'Reiche', 'fraktion': ''}
# {'vorname': 'Steffen', 'nachname': 'Kotré', 'fraktion': 'AfD'}
# {'vorname': 'Daniel', 'nachname': 'Walter', 'fraktion': 'SPD'}
# {'vorname': 'Katrin', 'nachname': 'Uhlig', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Jörg', 'nachname': 'Cezanne', 'fraktion': 'Die Linke'}
# {'vorname': 'Tilman', 'nachname': 'Kuban', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Raimond', 'nachname': 'Scheirich', 'fraktion': 'AfD'}
# {'vorname': 'Agnes', 'nachname': 'Conrad', 'fraktion': 'Die Linke'}
# {'vorname': 'Andreas', 'nachname': 'Lenz', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Andreas', 'nachname': 'Audretsch', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Dirk', 'nachname': 'Brandes', 'fraktion': 'AfD'}
# {'vorname': 'Bernd', 'nachname': 'Rützel', 'fraktion': 'SPD'}
# {'vorname': 'Michael', 'nachname': 'Kellner', 'fraktion': 'BÜNDNIS\xa090/DIE GRÜNEN'}
# {'vorname': 'Lars', 'nachname': 'Rohwer', 'fraktion': 'CDU/CSU'}
# {'vorname': 'Gerrit', 'nachname': 'Huy', 'fraktion': 'AfD'}
# {'vorname': 'Vanessa', 'nachname': 'Zobel', 'fraktion': 'CDU/CSU'}

# %%
import sys
sys.path.append("extr")
from redner_extraction import extract_all_speakers


political_party = []
for name, party in redner_party:
    political_party.append( party)

# %%
from collections import Counter
import matplotlib.pyplot as plt


poli_party = Counter(political_party)
print(poli_party)

labels = [p.replace("\xa0", " ") if p != "" else "Ministers" for p in poli_party.keys()]
poli_party_col = ["pink","blue", "red", "green", "purple", "black"]
labels_col = list(zip(labels, poli_party_col))

plt.bar(labels, list(poli_party.values()), color=poli_party_col, edgecolor='black')
plt.xticks(rotation=65)
plt.ylabel("Anzahl der Politiker")
plt.show()
# Out:
# Counter({'CDU/CSU': 23, 'AfD': 18, 'BÜNDNIS\xa090/DIE GRÜNEN': 11, 'SPD': 10, 'Die Linke': 7, '': 5})

# %%
for i, poli in enumerate(reden.keys()):
    print(f"die Länge der Reden von {poli} ist {len(reden[poli])} Zeichen.")
# Out:
# die Länge der Reden von Bärbel Bas ist 3926 Zeichen.
# die Länge der Reden von Hans-Jürgen Goßner ist 4801 Zeichen.
# die Länge der Reden von Wilfried Oellers ist 3031 Zeichen.
# die Länge der Reden von Ricarda Lang ist 5828 Zeichen.
# die Länge der Reden von Pascal Meiser ist 6894 Zeichen.
# die Länge der Reden von Dagmar Schmidt ist 4048 Zeichen.
# die Länge der Reden von Peter Bohnhof ist 8993 Zeichen.
# die Länge der Reden von Sandra Carstensen ist 3915 Zeichen.
# die Länge der Reden von Armin Grau ist 3252 Zeichen.
# die Länge der Reden von Nora Seitz ist 4075 Zeichen.
# die Länge der Reden von Leif-Erik Holm ist 4023 Zeichen.
# die Länge der Reden von Peter Aumer ist 4249 Zeichen.
# die Länge der Reden von Jan Dieren ist 3333 Zeichen.
# die Länge der Reden von Elisabeth Winkelmeier-Becker ist 3684 Zeichen.
# die Länge der Reden von Tobias Matthias Peterka ist 7068 Zeichen.
# die Länge der Reden von Axel Müller ist 5325 Zeichen.
# die Länge der Reden von Lena Gumnior ist 4502 Zeichen.
# die Länge der Reden von Mahmut Özdemir ist 10951 Zeichen.
# die Länge der Reden von Luke Hoß ist 5892 Zeichen.
# die Länge der Reden von Christian Moser ist 4917 Zeichen.
# die Länge der Reden von Rainer Galla ist 3157 Zeichen.
# die Länge der Reden von Maja Wallstein ist 5678 Zeichen.
# die Länge der Reden von Helge Limburg ist 3345 Zeichen.
# die Länge der Reden von Johannes Wiegelmann ist 5673 Zeichen.
# die Länge der Reden von Knuth Meyer-Soltau ist 2472 Zeichen.
# die Länge der Reden von David Preisendanz ist 3987 Zeichen.
# die Länge der Reden von Wolfram Weimer ist 3683 Zeichen.
# die Länge der Reden von Götz Frömming ist 4050 Zeichen.
# die Länge der Reden von Elisabeth Kaiser ist 3340 Zeichen.
# die Länge der Reden von Katrin Göring-Eckardt ist 4857 Zeichen.
# die Länge der Reden von Mandy Eißing ist 5435 Zeichen.
# die Länge der Reden von Ottilie Klein ist 2440 Zeichen.
# die Länge der Reden von Sven Wendorf ist 2917 Zeichen.
# die Länge der Reden von Franziska Kersten ist 3547 Zeichen.
# die Länge der Reden von Sepp Müller ist 2840 Zeichen.
# die Länge der Reden von Wolfgang Dahler ist 3886 Zeichen.
# die Länge der Reden von Birgit Bessin ist 3830 Zeichen.
# die Länge der Reden von Felix Döring ist 4645 Zeichen.
# die Länge der Reden von Misbah Khan ist 4043 Zeichen.
# die Länge der Reden von Konrad Körner ist 4673 Zeichen.
# die Länge der Reden von Anna Rathert ist 2926 Zeichen.
# die Länge der Reden von Reem Alabali Radovan ist 4768 Zeichen.
# die Länge der Reden von Rocco Kever ist 3614 Zeichen.
# die Länge der Reden von Nicolas Zippelius ist 3361 Zeichen.
# die Länge der Reden von Claudia Roth ist 3334 Zeichen.
# die Länge der Reden von Mirze Edis ist 7124 Zeichen.
# die Länge der Reden von Klaus Wiener ist 7537 Zeichen.
# die Länge der Reden von Johann Martel ist 2343 Zeichen.
# die Länge der Reden von Thomas Bareiß ist 3317 Zeichen.
# die Länge der Reden von Matthias Gastel ist 3835 Zeichen.
# die Länge der Reden von Michael Donth ist 5680 Zeichen.
# die Länge der Reden von Ulrich von Zons ist 2351 Zeichen.
# die Länge der Reden von Anja Troff-Schaffarzyk ist 3102 Zeichen.
# die Länge der Reden von Luigi Pantisano ist 3035 Zeichen.
# die Länge der Reden von Henning Rehbaum ist 2598 Zeichen.
# die Länge der Reden von Maximilian Kneller ist 4090 Zeichen.
# die Länge der Reden von Jakob Blankenburg ist 3439 Zeichen.
# die Länge der Reden von Günter Baumgartner ist 2443 Zeichen.
# die Länge der Reden von Katherina Reiche ist 5403 Zeichen.
# die Länge der Reden von Steffen Kotré ist 4144 Zeichen.
# die Länge der Reden von Daniel Walter ist 3504 Zeichen.
# die Länge der Reden von Katrin Uhlig ist 3922 Zeichen.
# die Länge der Reden von Jörg Cezanne ist 2718 Zeichen.
# die Länge der Reden von Tilman Kuban ist 3870 Zeichen.
# die Länge der Reden von Raimond Scheirich ist 2584 Zeichen.
# die Länge der Reden von Agnes Conrad ist 4824 Zeichen.
# die Länge der Reden von Andreas Lenz ist 3693 Zeichen.
# die Länge der Reden von Andreas Audretsch ist 5099 Zeichen.
# die Länge der Reden von Dirk Brandes ist 4196 Zeichen.
# die Länge der Reden von Bernd Rützel ist 5254 Zeichen.
# die Länge der Reden von Michael Kellner ist 5019 Zeichen.
# die Länge der Reden von Lars Rohwer ist 4291 Zeichen.
# die Länge der Reden von Gerrit Huy ist 5116 Zeichen.
# die Länge der Reden von Vanessa Zobel ist 4668 Zeichen.

# %%
# Boxplots der Redenlängen pro Fraktion (Nutzung vorhandener Variablen: data, labels, colors_for_boxes, plt)
plt.figure(figsize=(10, 6))
bp = plt.boxplot(data, patch_artist=True, labels=labels, showmeans=True,
                 meanprops={'marker': 'D', 'markerfacecolor': 'red', 'markeredgecolor': 'black'})

# Box-Farben setzen (falls colors_for_boxes nicht vorhanden ist, fallback auf colors)
box_colors = colors_for_boxes if 'colors_for_boxes' in globals() else (colors if 'colors' in globals() else None)
if box_colors:
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)

# feinere Formatierung
for whisker in bp.get('whiskers', []):
    whisker.set(color='black', linewidth=1)
for cap in bp.get('caps', []):
    cap.set(color='black', linewidth=1)
for median in bp.get('medians', []):
    median.set(color='black', linewidth=2)

plt.xticks(rotation=45, ha='right')
plt.ylabel("Redenlänge (Zeichen)")
plt.title("Verteilung der Redenlängen pro Fraktion")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_5828\2837248900.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(data, patch_artist=True, labels=labels, showmeans=True,

# %%
# Out:
# [('Ministers', 'pink'),
#  ('AfD', 'blue'),
#  ('CDU/CSU', 'red'),
#  ('BÜNDNIS 90/DIE GRÜNEN', 'green'),
#  ('Die Linke', 'purple'),
#  ('SPD', 'black')]

# %%
party_speech_len = {"AfD": [], "CDU/CSU": [], "BÜNDNIS\xa090/DIE GRÜNEN": [], "Die Linke": [], "SPD": [], "": []}

for poli, party in redner_party:
    party_speech_len[party].append(len(reden[poli]))


party_speech_len    

plt.boxplot(party_speech_len.values(), labels=party_speech_len.keys())
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_5828\423539113.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(party_speech_len.values(), labels=party_speech_len.keys())
